# %%
# %pip install pandas seaborn scikit-learn

# %%
import sklearn.datasets as datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
from sklearn import tree
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
iris_df=pd.read_csv("iris.csv")
iris_df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris_df.isnull().any()
# Out:
# sepal.length    False
# sepal.width     False
# petal.length    False
# petal.width     False
# variety         False
# dtype: bool

# %%
iris_df.dtypes
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %%
iris_df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sns.pairplot(iris_df,hue='variety')
plt.savefig("exercise2a.png")
plt.show()

# %%
X=iris_df[['sepal.length','sepal.width','petal.length','petal.width']].values
y=iris_df['variety'].values
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.9,random_state=1)
clf=tree.DecisionTreeClassifier()
clf=clf.fit(X_train,y_train)
prediction=clf.predict(X_test)
prediction
# Out:
# array(['Setosa', 'Versicolor', 'Versicolor', 'Setosa', 'Virginica',
#        'Versicolor', 'Virginica', 'Setosa', 'Setosa', 'Virginica',
#        'Versicolor', 'Setosa', 'Virginica', 'Versicolor', 'Versicolor'],
#       dtype=object)

# %%
print(classification_report(y_test,prediction))
# Out:
#               precision    recall  f1-score   support
#
#       Setosa       1.00      1.00      1.00         5
#   Versicolor       1.00      1.00      1.00         6
#    Virginica       1.00      1.00      1.00         4
#
#     accuracy                           1.00        15
#    macro avg       1.00      1.00      1.00        15
# weighted avg       1.00      1.00      1.00        15

# %%
ConfusionMatrixDisplay.from_estimator(clf,X_test,y_test)
plt.savefig("excercise2b.png")
plt.show()

# %%
# !pip install pydotplus
# !pip install graphviz
# Out:
# Collecting pydotplus
#   Downloading pydotplus-2.0.2.tar.gz (278 kB)
#      |████████████████████████████████| 278 kB 2.5 MB/s eta 0:00:01
# Requirement already satisfied: pyparsing>=2.0.1 in ./.local/lib/python3.8/site-packages (from pydotplus) (3.1.4)
# Building wheels for collected packages: pydotplus
#   Building wheel for pydotplus (setup.py) ... done
#   Created wheel for pydotplus: filename=pydotplus-2.0.2-py3-none-any.whl size=24566 sha256=22df5046bfaacd4b95f33942d9b2aaa6389d9f9e139f8ce842a7e9e39fa1ae7c
#   Stored in directory: /home/aidslab109/.cache/pip/wheels/fe/cd/78/a7e873cc049759194f8271f780640cf96b35e5a48bef0e2f36
# Successfully built pydotplus
# Installing collected packages: pydotplus
# Successfully installed pydotplus-2.0.2
# Collecting graphviz
#   Downloading graphviz-0.20.3-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 3.2 MB/s eta 0:00:01
# Installing collected packages: graphviz
# Successfully installed graphviz-0.20.3

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, plot_tree
iris = load_iris()
X = iris.data
y = iris.target
clf = DecisionTreeClassifier(max_depth=3, random_state=42)
clf.fit(X, y)
plt.figure(figsize=(12, 8))
plot_tree(clf, 
          feature_names=['sepal.length', 'sepal.width', 'petal.length', 'petal.width'], 
          class_names=iris.target_names, 
          filled=True, 
          rounded=True)
plt.savefig("exercise2b.png", bbox_inches='tight')
plt.show()

# %%
SepalLengthCm = 4.8
SepalWidthCm = 2.9
PetalLengthCm = 1.3
PetalWidthCm = 0.2

x = [[SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm]]
res = clf.predict(x)

class_mapping = {0: 'setosa', 1: 'versicolor', 2: 'virginica'}
predicted_class = class_mapping[res[0]]

print("The class predicted is --> " + predicted_class)
# Out:
# The class predicted is --> setosa
